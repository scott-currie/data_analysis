# %% [markdown]
# # Code 16: Data Analysis
# ## Scott Currie
# ## Cycle Share Dataset

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
trips = pd.read_csv('./trip.csv')

# %%
trips.sample(10)
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 13465     16795  11/24/2014 12:28  11/24/2014 12:35  SEA00273       401.792
# 152995   113691   7/21/2015 18:19   7/21/2015 18:24  SEA00216       333.513
# 108254    66111    4/30/2015 9:16    4/30/2015 9:28  SEA00260       722.025
# 39175     46659   3/13/2015 12:58   3/13/2015 13:09  SEA00161       666.896
# 91523     48329    3/19/2015 9:23    3/19/2015 9:45  SEA00252      1346.758
# 265689   233176   7/13/2016 12:43   7/13/2016 12:46  SEA00129       135.131
# 15907     19916    12/8/2014 9:42    12/8/2014 9:53  SEA00323       637.553
# 199033   162488   10/29/2015 7:24   10/29/2015 7:29  SEA00388       251.605
# 245825   212271   5/22/2016 15:00   5/22/2016 15:15  SEA00455       945.781
# 174003   136005    8/27/2015 8:34    8/27/2015 8:41  SEA00237       473.751
#
#                                         from_station_name  \
# 13465                                 1st Ave & Marion St
# ...

# %%
trips.describe()
# Out:
#              trip_id   tripduration      birthyear
# count  286858.000000  286858.000000  181553.000000
# mean   112431.781746    1178.354284    1979.759062
# std     76565.086482    2038.697070      10.167119
# min       431.000000      60.008000    1931.000000
# 25%     43051.000000     387.925750    1974.000000
# 50%    103486.500000     624.846500    1983.000000
# 75%    179544.750000    1118.483250    1987.000000
# max    255245.000000   28794.398000    1999.000000

# %% [markdown]
# ### 1. What is the average trip duration for a borrowed bicycle?

# %%
avg_trip_duration = trips.tripduration.mean()

# %%
print(f'The average trip lasted { avg_trip_duration } seconds.')
# Out:
# The average trip lasted 1178.3542840325176 seconds.

# %% [markdown]
# ### 2. What’s the most common age of a bicycle-sharer?
# - Subtract rider birth year from ride date
# - Add rider age to data
# - Get most common age

# %%
most_common_birthyr = trips['birthyear'].value_counts().idxmax()

# %%
trips['age'] = dt.datetime(trips['starttime']) - trips['birthyear']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d0b47deea09c> in <module>
# ----> 1 trips['age'] = dt.datetime(trips['starttime']) - trips['birthyear']
#
# ~/.local/share/virtualenvs/data_analysis-dUrlud77/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
trips.head(10)
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# 5      436  10/13/2014 10:34  10/13/2014 10:47  SEA00337       808.805
# 6      437  10/13/2014 11:35  10/13/2014 11:45  SEA00202       596.715
# 7      438  10/13/2014 11:35  10/13/2014 11:45  SEA00311       592.131
# 8      439  10/13/2014 11:35  10/13/2014 11:45  SEA00486       586.347
# 9      440  10/13/2014 11:35  10/13/2014 11:45  SEA00434       587.634
#
#                                    from_station_name  \
# 0                                2nd Ave & Spring St
# 1                                2nd Ave & Spring St
# ...

# %% [markdown]
# ### 3. Given all the weather data here, find the average precipitation per month, and the median precipitation.

# %%
wdf = pd.read_csv('./weather.csv')

# %%
wdf.sample(10)
# Out:
#            Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 583   5/18/2016                 64                60.0                54
# 59   12/11/2014                 60                55.0                50
# 410  11/27/2015                 48                39.0                30
# 40   11/22/2014                 51                48.0                45
# 370  10/18/2015                 62                60.0                59
# 490   2/15/2016                 57                54.0                51
# 358   10/6/2015                 66                60.0                54
# 343   9/21/2015                 66                60.0                55
# 105   1/26/2015                 64                55.0                46
# 198   4/29/2015                 64                56.0                48
#
#      Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 583               53               50              45            87
# ...

# %%
avg_precip = wdf.Precipitation_In.mean()

# %%
median_precip = wdf.Precipitation_In.median()
